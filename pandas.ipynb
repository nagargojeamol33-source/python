# %%
import numpy as np 

import pandas as pd

# %%
data_1 = {
    "ID" : [1,2,3],
    "Name" : ["Adi","Sham","Sai"]
}

# %%
print(type(data_1))
# Out:
# <class 'dict'>

# %%
data_1
# Out:
# {'ID': [1, 2, 3], 'Name': ['Adi', 'Sham', 'Sai']}

# %%
data_1 = pd.DataFrame(data_1)

data_1
# Out:
#    ID  Name
# 0   1   Adi
# 1   2  Sham
# 2   3   Sai

# %%
print(type(data_1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data_2 = {
    "ID" : [1,2,3],
    "City":["Pune","Nashik","Pune"],
    "Marks":[89,87,56]
}

# %%
data_2
# Out:
# {'ID': [1, 2, 3], 'City': ['Pune', 'Nashik', 'Pune'], 'Marks': [89, 87, 56]}

# %%
data_2 = pd.DataFrame(data_2)

# %%
data_1
# Out:
#    ID  Name
# 0   1   Adi
# 1   2  Sham
# 2   3   Sai

# %%
data_2
# Out:
#    ID    City  Marks
# 0   1    Pune     89
# 1   2  Nashik     87
# 2   3    Pune     56

# %%
data_all = pd.merge(data_1,data_2 , on="ID")

data_all
# Out:
#    ID  Name    City  Marks
# 0   1   Adi    Pune     89
# 1   2  Sham  Nashik     87
# 2   3   Sai    Pune     56

# %%
data_all["Name"]
# Out:
# 0     Adi
# 1    Sham
# 2     Sai
# Name: Name, dtype: object

# %%
data_all["City"]
# Out:
# 0      Pune
# 1    Nashik
# 2      Pune
# Name: City, dtype: object

# %%
New_data = data_all[["Name","ID","Marks"]]

# %%
New_data
# Out:
#    Name  ID  Marks
# 0   Adi   1     89
# 1  Sham   2     87
# 2   Sai   3     56

# %%
'''
D_1 = [Name , ID ]

D2  = [Name , City , Marks]

D3 = [ID,Grade]

master = [ID , Name , Marks , Grade , City ]

'''
# Out:
# '\nD_1 = [Name , ID ]\n\nD2  = [Name , City , Marks]\n\nD3 = [ID,Grade]\n\nmaster = [ID , Name , Marks , Grade , City ]\n\n'

# %%
d_1 = {
    "ID" : [1,2,3],
    "Name" : ["Adi","Sham","Sai"]
}

d_1 = pd.DataFrame(d_1)

# %%
d_2 = {
    "Name" : ["Adi","Sham","Sai"],
    "City":["Pune","Nashik","Pune"],
    "Marks":[89,87,56]   
}

d_2 = pd.DataFrame(d_2)

# %%
d_3 = {
     "ID" : [1,2,3],
     "Grade":["A","B","A"]
}

d_3 = pd.DataFrame(d_3)

# %%
d_1
# Out:
#    ID  Name
# 0   1   Adi
# 1   2  Sham
# 2   3   Sai

# %%
d_2
# Out:
#    Name    City  Marks
# 0   Adi    Pune     89
# 1  Sham  Nashik     87
# 2   Sai    Pune     56

# %%
d_3
# Out:
#    ID Grade
# 0   1     A
# 1   2     B
# 2   3     A

# %%
A = pd.merge(d_1,d_2,on="Name")

# %%
master = pd.merge(A,d_3,on="ID")

# %%
master
# Out:
#    ID  Name    City  Marks Grade
# 0   1   Adi    Pune     89     A
# 1   2  Sham  Nashik     87     B
# 2   3   Sai    Pune     56     A

# %%
master = master[["ID","Name","Marks","Grade","City"]]

master
# Out:
#    ID  Name  Marks Grade    City
# 0   1   Adi     89     A    Pune
# 1   2  Sham     87     B  Nashik
# 2   3   Sai     56     A    Pune

# %% [markdown]
# # basic EDA

# %%
df = pd.read_excel(r"C:\Users\Dell\Desktop\Excel Sheet\SuperStore Sales DataSet (4).xlsx")

# %%
df.shape
# Out:
# (5905, 22)

# %%
df.head(3)
# Out:
#    Row ID+O6G3A1:R6        Order ID Order Date    Month  Ship Date  \
# 0            4918.0  CA-2019-160304 2019-01-01  January 2019-01-07
# 1            4919.0  CA-2019-160304 2019-01-02  January 2019-01-07
# 2            4920.0  CA-2019-160304 2019-01-02  January 2019-01-07
#
#         Ship Mode Customer ID  Customer Name    Segment        Country  ...  \
# 0  Standard Class    BM-11575  Brendan Murry  Corporate  United States  ...
# 1  Standard Class    BM-11575  Brendan Murry  Corporate  United States  ...
# 2  Standard Class    BM-11575  Brendan Murry  Corporate  United States  ...
#
#   Region       Product ID    Category Sub-Category  \
# 0   East  FUR-BO-10004709   Furniture    Bookcases
# 1   East  FUR-BO-10004709   Furniture    Bookcases
# 2   East  TEC-PH-10000455  Technology       Phones
#
#                                         Product Name   Sales Quantity  \
# 0  Bush Westfield Collection Bookcases, Medium Ch...   73.94      1.0
# ...

# %%
df.tail(5)
# Out:
#       Row ID+O6G3A1:R6        Order ID Order Date     Month  Ship Date  \
# 5900            5093.0  CA-2020-151450 2020-12-31  December 2021-01-04
# 5901               NaN             NaN        NaT       NaN        NaT
# 5902               NaN             NaN        NaT       NaN        NaT
# 5903               NaN             NaN        NaT       NaN        NaT
# 5904               NaN             NaN        NaT       NaN        NaT
#
#            Ship Mode Customer ID  Customer Name   Segment        Country  ...  \
# 5900  Standard Class    JM-15580  Jill Matthias  Consumer  United States  ...
# 5901             NaN         NaN            NaN       NaN            NaN  ...
# 5902             NaN         NaN            NaN       NaN            NaN  ...
# 5903             NaN         NaN            NaN       NaN            NaN  ...
# 5904             NaN         NaN            NaN      5754            NaN  ...
#
#      Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5905 entries, 0 to 5904
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   float64
#  1   Order ID          5901 non-null   object
#  2   Order Date        5901 non-null   datetime64[ns]
#  3   Month             5901 non-null   object
#  4   Ship Date         5901 non-null   datetime64[ns]
#  5   Ship Mode         5901 non-null   object
#  6   Customer ID       5901 non-null   object
#  7   Customer Name     5901 non-null   object
#  8   Segment           5902 non-null   object
#  9   Country           5901 non-null   object
#  10  City              5901 non-null   object
#  11  State             5901 non-null   object
#  12  Region            5901 non-null   object
#  13  Product ID        5901 non-null   object
#  14  Category          5901 non-null   object
#  15  Sub-Category      5901 non-null   object
# ...

# %%
pd.isnull(df).sum()
# Out:
# Row ID+O6G3A1:R6    4
# Order ID            4
# Order Date          4
# Month               4
# Ship Date           4
# Ship Mode           4
# Customer ID         4
# Customer Name       4
# Segment             3
# Country             4
# City                4
# State               4
# Region              4
# Product ID          4
# Category            4
# Sub-Category        4
# Product Name        4
# Sales               4
# Quantity            4
# Profit              4
# Returns             4
# Payment Mode        4
# dtype: int64

# %%
df.columns
# Out:
# Index(['Row ID+O6G3A1:R6', 'Order ID', 'Order Date', 'Month', 'Ship Date',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country',
#        'City', 'State', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Profit', 'Returns',
#        'Payment Mode'],
#       dtype='object')

# %% [markdown]
# # Basic DC

# %%
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# Row ID+O6G3A1:R6    0
# Order ID            0
# Order Date          0
# Month               0
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Country             0
# City                0
# State               0
# Region              0
# Product ID          0
# Category            0
# Sub-Category        0
# Product Name        0
# Sales               0
# Quantity            0
# Profit              0
# Returns             0
# Payment Mode        0
# dtype: int64

# %%
df.rename(columns={"Order ID":"OID"},inplace=True)

# %%
df.columns
# Out:
# Index(['Row ID+O6G3A1:R6', 'OID', 'Order Date', 'Month', 'Ship Date',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country',
#        'City', 'State', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Profit', 'Returns',
#        'Payment Mode'],
#       dtype='object')

# %%
df.rename(columns={"Product ID":"PID"},inplace=True)

# %%
df.drop('Row ID+O6G3A1:R6',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['OID', 'Order Date', 'Month', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Region', 'PID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Profit', 'Returns', 'Payment Mode'],
#       dtype='object')

# %% [markdown]
# # DF
