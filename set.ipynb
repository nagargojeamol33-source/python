# %%
A = {"AMOL" , 5 , "SHAM"}

# %%
print(type(A))
# Out:
# <class 'set'>

# %%
B = { 1,3,2,4,2,5,6,5,7,4,3,32,34,4,5,}

# %%
print(type(B))
# Out:
# <class 'set'>

# %%
len(B)
# Out:
# 9

# %%
print(B)
# Out:
# {32, 2, 3, 4, 5, 6, 7, 34}

# %%
B.pop()
# Out:
# 32

# %%
B.popitem()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 B.popitem()
#
# AttributeError: 'set' object has no attribute 'popitem'
