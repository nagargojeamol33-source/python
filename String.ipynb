# %%
# " "
# [  ]

# ( )

# { }

# %%
A  = "Python is best"

# %%
print(type(A))
# Out:
# <class 'str'>

# %%
print(A[-6])
# Out:
# s

# %%
print(len(A))
# Out:
# 14

# %%
print(A[5])
# Out:
# n

# %% [markdown]
# # Slicing

# %%
# [ Start : Stop : Step ]

# %%
A  = "Sham is the best student in the class"

# %%
len(A)
# Out:
# 33

# %%
print(A[12:16:1])
# Out:
# best

# %%
print(A[17:24:1])
# Out:
# student

# %%
A  = "Sham is the best student in the class"

# %%
# bs tdn n

print(A[12:27:2])
# Out:
# bs tdn n

# %%
print(A[::-1])
# Out:
# ssalc eht ni tneduts tseb eht si mahS

# %% [markdown]
# # Text Function

# %%
data = "Namesh"

# %%
print(data.upper())
# Out:
# NAMESH

# %%
print(data.lower())
# Out:
# namesh

# %%
A = "Sai"

B = "Patil"

# %%
Full_Name = A + B

# %%
F_Name = A + " " + B

# %%
F_Name
# Out:
# 'Sai Patil'

# %%
A = "ADITYA" # AdITyA 

print("AdITyA")
# Out:
# AdITyA

# %%
print(A[0]+A[1].lower()+A[2:4:1]+A[4].lower()+A[5])
# Out:
# AdITyA

# %%
D = "PYTHON"

# PYthoN
