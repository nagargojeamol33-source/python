# %%
# tupple ( ) round bracket .
# usse kadhi hot list changeble aste jrr tila unchangeable krych asel trr conver krych topple madhe 
# list and tupple are 80% same list is mutuable tupple is immuteble.
#

# %%
A = ["a","b","c",["sai","sham","manoj"],"sahill","aditya",[1,2,3,"d1"],"r","t","tejas"]

# %%
W =('list, and tupple, are, 80% same ,lis,t ,is mutuable, tupple, is ,immuteble',)
print(type(W))
# Out:
# <class 'tuple'>

# %%
A[5][-2]= "aditya"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 A[5][-2]= "aditya"
#
# TypeError: 'str' object does not support item assignment

# %%
print(A)
# Out:
# ['a', 'b', 'c', ['sai', 'sham', 'manoj'], 'sahill', 'aditya', [1, 2, 3, 'd1'], 'r', 't', 'tejas']

# %%
v = (

# %%
A[5][-2] = "aditya"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 A[5][-2] = "aditya"
#
# TypeError: 'str' object does not support item assignment

# %%
A[3][-1]="aditya"

# %%
print(A)
# Out:
# ['a', 'b', 'c', ['sai', 'sham', 'aditya'], 'sahill', 'aditya', [1, 2, 3, 'd1'], 'r', 't', 'tejas']

# %%
A[6][-2] = "aditya"

# %%
print(A)
# Out:
# ['a', 'b', 'c', ['sai', 'sham', 'aditya'], 'sahill', 'aditya', [1, 2, 'aditya', 'd1'], 'r', 't', 'tejas']

# %%
print(type(A))
# Out:
# <class 'list'>

# %%
data = ('amol',)
print(type(data))
# Out:
# <class 'tuple'>

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
d = ('amolllll')

# %%
type(d)
# Out:
# str

# %%
q = 'qwfrgrgnjg'

# %%
type(q)
# Out:
# str

# %%
data = ('tribute Error')
type(data)
# Out:
# str

# %%
A = (1,2,3,(1,2,3),1,4)

# %%
print(type(A))
# Out:
# <class 'tuple'>

# %%
B = ('AMOL','sham')
print(type(B))
# Out:
# <class 'tuple'>

# %%
n = 'amolll',

# %%
print(type(n))
# Out:
# <class 'tuple'>

# %%
print('amolll'in n)
# Out:
# True

# %%
a = ('amol',)
print(type(a))
# Out:
# <class 'tuple'>

# %%
A = (1,2,3,(1,2,3),1,4)
print(type(A))
# Out:
# <class 'tuple'>

# %%
print(type(A))
# Out:
# <class 'tuple'>

# %%
print(type(A))
# Out:
# <class 'tuple'>

# %%
D = list(A)
D3= list(A[3])
print(D)
print(type(D))
# Out:
# [1, 2, 3, (1, 2, 3), 1, 4]
# <class 'list'>

# %%
D[3].remove(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 D[3].remove(2)
#
# AttributeError: 'tuple' object has no attribute 'remove'
