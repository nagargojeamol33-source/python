# %% [markdown]
# 1 :- Atribute Error
#
# it occurs when you applies wrong methode on wrong data.....
#
#   it means the commends is not valide or cant perform by this data in this feature....

# %% [markdown]
# Type Error
# string and int
# when you apply wrong opration on wrong data type...
