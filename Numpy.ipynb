# %%
import numpy as np


# what is numpy 

# why use numpy

# %%
data = [1,2,3,4,5,6,7]

# %%
data = np.array(data)

# %%
print(data)
# Out:
# [1 2 3 4 5 6 7]

# %%
type(data)
# Out:
# numpy.ndarray

# %%
data.ndim
# Out:
# 1

# %%
data.dtype
# Out:
# dtype('int32')

# %%
print(len(data))
# Out:
# 7

# %%
data.size
# Out:
# 7

# %%
data.shape
# Out:
# (7,)

# %%
data
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
data[1:5:1]
# Out:
# array([2, 3, 4, 5])

# %% [markdown]
# # 1D array

# %%
D1 = np.array([1,2,3])

print(D1)

print(D1.ndim)

print(D1.size)

print(D1.shape)

print(D1.dtype)
# Out:
# [1 2 3]
# 1
# 3
# (3,)
# int32

# %% [markdown]
# # 2D array

# %%
D2 = np.array([[22,33,44],[45,67,78],[67,87,45],[34,67,98]])


print(D2)

print(D2.ndim)

print(D2.size)

print(D2.shape)

print(D2.dtype)
# Out:
# [[22 33 44]
#  [45 67 78]
#  [67 87 45]
#  [34 67 98]]
# 2
# 12
# (4, 3)
# int32

# %% [markdown]
# # 3D array

# %%
D3 = np.array([[[12,45,67],[45,67,89]]])

# %%
print(type(D3))

print(D3.ndim)

print(D3.size)

print(D3.shape)

print(D3.dtype)
# Out:
# <class 'numpy.ndarray'>
# 3
# 6
# (1, 2, 3)
# int32

# %% [markdown]
# # Function

# %%
data = [22,45,67,8,9,99,89,56,45,34,23,12,67]

# %%
data = np.array(data)

# %%
data
# Out:
# array([22, 45, 67,  8,  9, 99, 89, 56, 45, 34, 23, 12, 67])

# %%
data.max()
# Out:
# 99

# %%
data.min()
# Out:
# 8

# %%
D = np.array([2,4,6])

B = np.array([1,2,4])


T = D+B
print(T)
# Out:
# [ 3  6 10]

# %%
Y = D * D

print(Y)
# Out:
# [ 4 16 36]

# %%
U = D * 2 

print(U)
# Out:
# [ 4  8 12]

# %%
Avg = data.mean()

# %%
Avg = int(Avg)

print(Avg)
# Out:
# 44

# %%
count_of_data = data.size

count_of_data
# Out:
# 13

# %%
sum_of_data = sum(data)

# %%
Avg_2 = sum_of_data / count_of_data

print(f"{Avg_2}  ------ {Avg}")
# Out:
# 44.30769230769231  ------ 44
